# %% [markdown]
# # main scenarios

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import sys
# if 'google.colab' in str(get_ipython()):
#     ! {sys.executable} -m pip install pytorch-lifestream

# %%
import os
# !pip install pytorch-lifestream@git+https://github.com/maximvw/pytorch-lifestream
# !pip install torch==1.12.1
# Out:
# ...
#   Cloning https://github.com/maximvw/pytorch-lifestream to /tmp/pip-install-s0foiqp0/pytorch-lifestream_7b796c03382f4da08152cdc033de17da
#   Running command git clone --filter=blob:none --quiet https://github.com/maximvw/pytorch-lifestream /tmp/pip-install-s0foiqp0/pytorch-lifestream_7b796c03382f4da08152cdc033de17da
#   Resolved https://github.com/maximvw/pytorch-lifestream to commit 03c02d9b674a23dcdb6e5aa60606902648dd8956
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.3/802.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 10.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Other libs

# %%
# !pip install pytorch-lightning==1.8.5
# !pip install luigi
# !pip install hydra-core
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.2.5
#     Uninstalling pytorch-lightning-2.2.5:
#       Successfully uninstalled pytorch-lightning-2.2.5
# ...

# %%
# !git clone https://github.com/dllllb/ptls-validation.git
os.chdir('ptls-validation')
# !git bundle create embeddings_validation.bundle HEAD master
# !python3 setup.py install
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for luigi: filename=luigi-3.5.1-py3-none-any.whl size=1085892 sha256=4ea3993f8178cfa03f97cadf5953d58b3ec6cd14966580bbcdac052d4f72efca
#   Stored in directory: /root/.cache/pip/wheels/2f/29/d0/ce41e9ade7b431829975e6d3f275a8a33625104bc128150cc1
# Successfully built luigi
# ...

# %%
# !pip install torchvision==0.12.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
#       Successfully uninstalled torchvision-0.18.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lifestream 0.6.0 requires torch>=1.12.0, but you have torch 1.11.0 which is incompatible.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 1.11.0 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.11.0 which is incompatible.
# ...

# %%
import os
import pandas as pd
import numpy as np

# path to scenario in ptls-experimnets
path_to_scenario = ''


os.chdir(path_to_scenario)

# %%
# !export CUDA_VISIBLE_DEVICES=0  # define here one gpu device number

# !sh bin/run_all_scenarios.sh
# Out:
# ==== Folds split
# rm: cannot remove 'lightning_logs/': No such file or directory
# rm: cannot remove 'conf/embeddings_validation.work/': No such file or directory
# /usr/local/lib/python3.10/dist-packages/luigi/parameter.py:296: UserWarning: Parameter "conf" with value "<embeddings_validation.config.Config object at 0x7d9f08d0c7c0>" is not of type string.
#   warnings.warn('Parameter "{}" with value "{}" is not of type string.'.format(param_name, param_value))
# [2024-06-11 21:01:06,056][luigi][INFO] - logging configured by default settings
# INFO: Informed scheduler that task   FoldSplitter__embeddings_vali_6cd0f172f4   has status   DONE
# [2024-06-11 21:01:06,062][luigi-interface][INFO] - Informed scheduler that task   FoldSplitter__embeddings_vali_6cd0f172f4   has status   DONE
# INFO: Done scheduling tasks
# [2024-06-11 21:01:06,062][luigi-interface][INFO] - Done scheduling tasks
# INFO: Running Worker with 10 processes
# ...
